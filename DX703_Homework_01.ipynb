# %% [markdown]
# # Homework 01: Binary Classification with Neural Networks
#
# ## Due: Sunday Sept 6th @ 11:59 (with 2-hour + 1-minute grace period) and worth 85 points
#
# ## Note: For this first assignment, there will be no late points if received by Sept 11th @ 11:59 pm
#
# In this assignment, you'll build your first deep learning models using **Keras**, a high-level deep learning framework built on TensorFlow.
#
# We’ll solve a binary classification task, using the Wisconsin Breast Cancer dataset.
#
# You’ll start by training a simple baseline model, and then explore a series of alternate network designs.  For each model, you’ll:
#
# - Track training loss and accuracy over epochs
# - Report final test set performance (loss and accuracy)
#
# The goal is to begin developing an intuition for how network design choices influence performance—and to get comfortable with the end-to-end modeling workflow in Keras.
#
#
# There are 12 graded problems, each worth 7 points, and you get 1 point free.

# %%
# Useful Imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import class_weight

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Sequential

random_seed = 42
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788723191.788004   18248 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1788723191.865650   18248 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788723195.260751   18248 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# Utility function: Plotting Training Loss (x-entropy) and Accuracy
# We'll replace this with a different function train_and_test when we develop more
# training techniques.

# Takes the history object returned by fit

def plot_history(history):
    n_epochs = len(history.history['accuracy'])
    epochs = range(1, n_epochs + 1)

    plt.figure(figsize=(7, 8))

    plt.subplot(2, 1, 1)
    plt.plot(epochs, history.history['loss'], label='Training Loss (Xent)', color='tab:red')
    plt.ylabel('Loss')
    plt.title('Training Loss')
    plt.grid(True)
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(epochs, history.history['accuracy'], label='Training Accuracy', color='tab:blue')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim(0, 1.05)
    plt.title('Training Accuracy')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

    final_loss = history.history['loss'][-1]
    final_acc = history.history['accuracy'][-1]
    print(f'Final Training Loss:     {final_loss:.4f}')
    print(f'Final Training Accuracy: {final_acc:.4f}')

# %% [markdown]
# ## Prelude: Load and Explore the Wisconsin Breast Cancer Dataset
#
# You should **always** perform EDA when working with a new dataset. We've seen this one before, but its always worth becoming familiar with the data before building a model!

# %%
# Load dataset with as DataFrame for EDA
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer(as_frame=True)

df = data.frame  # Convenient alias for combined data+target

# %%
# Uncomment and look at this

# df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  target                   569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
# Uncomment and look at this

fig = df.hist(bins=20, figsize=(20, 15), layout=(6, 6))
plt.suptitle("\nHistograms of All Features in Breast Cancer Dataset", fontsize=32)
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Leave space for the title
plt.show()

# %% [markdown]
# ## Problem One: Dealing with unbalanced target variables and establishing a baseline model
#
# ### Part A: Compute the imbalance of the target
#
# Neural networks work best with standardized datasets; for classification tasks, it is also important
# to account for an unbalanced target. Let's create our `X,y` data structure and look at the target more closely.
#
# 1. **Convert the data to NumPy arrays:** Extract the feature matrix `X` and the target vector `y` from the DataFrame, and
# convert them to NumPy arrays. Print the shapes of `X` and `y` to confirm the conversion was successful.
#
# 2. **Check for class imbalance:**
#    Use `Counter` (or another appropriate method) to print the frequency of each class label in the target array `y`. This will help you understand how balanced (or imbalanced) the classes are.
#
# 3. **Compute the proportion of class 1:**
#    Calculate what percentage of the samples belong to class label `1` and provide your answer in the graded question.

# %%
# A.1: Convert the data to NumPy Arrays

X = df.drop("target", axis=1).to_numpy()
y = df["target"].to_numpy()

# %%
# A.2: Check for Class Imbalance

class_counts = Counter(y)

print(class_counts)
# Out:
# Counter({np.int64(1): 357, np.int64(0): 212})

# %%
# A.3: Compute the proportion of class 1

# Set a1a to the percentage (a float between 0 and 1) of 1's in the target
# Use an expression, not constants derived from inspecting the data

a1a = class_counts[1] / len(y)

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a1a = {a1a:.4f}')
# Out:
# a1a = 0.6274

# %% [markdown]
# ### Part B: Perform a stratified test/train split
#
# In classification problems with imbalanced datasets, it's important to address the class imbalance so that the model doesn't become biased toward the majority class. There are two common strategies:
#
# * **Resampling** the dataset to balance the classes (by oversampling the minority class or undersampling the majority class).
# * **Adjusting the loss function** so that errors on minority classes have more influence during training.
#
# In this problem, you'll explore the second approach—using class weights to influence how the model learns.
#
# This strategy involves two key steps:
#
# 1. **Preserve class proportions in the train/test split**
#    Use the  parameter `stratify=y`in `train_test_split` to ensure that both the training and testing sets maintain the same class distribution as in the original target.
#
# 2. **Apply class weighting during training**
#    Use the `class_weight` parameter in the `fit` function to assign different weights to each class when computing the loss. This helps ensure that the model pays appropriate attention to both common and rare classes.
#
#
# **We'll do the first step now, perform standardization, and then do the second step in Part C.**

# %%
# Perform train-test split, keeping both stratified, use random_state = random_seed and test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    stratify=y,
                                                    test_size = 0.2, 
                                                    random_state=42)

# %%
# Check proportions were preserved in train/test split

print("Original class 1 proportion:", np.mean(y == 1))
print("Training class 1 proportion:", np.mean(y_train == 1))
print("Testing class 1 proportion:", np.mean(y_test == 1))
# Out:
# Original class 1 proportion: 0.6274165202108963
# Training class 1 proportion: 0.6263736263736264
# Testing class 1 proportion: 0.631578947368421

# %% [markdown]
# **(Digression:** We must perform standardization **after** the test/train split, or else we're letting
# information about the mean and standard deviation of the test set influence training--a classic case of *data leakage*.
# **)**

# %%
# As usual, standardize the features

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f'X_train_scaled.shape = {X_train_scaled}')
print(f'X_test_scaled.shape = {X_test_scaled}')
# Out:
# X_train_scaled.shape = [[-1.07200079 -0.6584246  -1.0880801  ... -1.35052668 -0.35265805
#   -0.54138003]
#  [ 1.74874285  0.06650173  1.75115682 ...  1.54991557  0.19107787
#   -0.1737386 ]
#  [-0.97473376 -0.93112416 -0.99770871 ... -1.70744192 -0.307734
#   -1.21303263]
#  ...
#  [ 0.39844772  1.06867262  0.50751384 ...  1.53492543  0.16164487
#    1.23754763]
#  [ 0.85331409 -0.0380331   0.9054796  ...  2.10455077  0.31035897
#    0.36249578]
#  [-0.91179628 -0.82431683 -0.87666079 ... -0.51332734 -0.50756857
#    1.30824791]]
# X_test_scaled.shape = [[ 1.56851278  2.16401585  1.74286587 ...  1.20214432 -0.14043064
#    0.90036171]
#  [-0.84027641 -0.5970672  -0.8741735  ... -1.10124064 -0.81429139
#   -0.71323608]
#  [-0.07072262  1.19138742  0.03202768 ...  0.57255843  1.14997397
#    1.86841162]
#  ...
#  [ 0.3583966  -0.44935493  0.48264098 ...  1.63386036  0.54117564
#    1.91191948]
#  [-0.41401799  1.07321761 -0.42314565 ...  0.06139464 -0.1280378
#    0.64747227]
#  [-0.6829327  -0.69932953 -0.66607058 ... -0.23615965 -0.16211811
#   -0.20147486]]

# %% [markdown]
# Let's see if the stratification worked! Assign `a1b` to the percentage of 1's in `y_train` (and convince yourself that if it is approximately correct, then so must be `y_test`).

# %%
# Set a1b to the percentage (a float between 0 and 1) of 1's in the target
# Use an expression, not constants derived from inspecting the data

a1b = np.mean(y_train == 1)            # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a1b = {a1b:.4f}')
# Out:
# a1b = 0.6264

# %% [markdown]
# ## Part C: Train a baseline model with class weighting
#
# Now we'll build a baseline model with class weighting during training.
#
# To compute the weight for class $i$, use the following formula:
#
# $$
# \text{weight}_i = \frac{n}{k \cdot n_i},
# $$
#
# where:
#
# * $n$ is the total number of samples,
# * $n_i$ is the number of samples in class $i$,
# * $k$ is the total number of classes.
#
# This formula scales the loss so that each class contributes approximately equally during training—without changing the number of training samples.
#
# To apply class weighting during training, we use the parameter `class_weight=weights` in the `fit` function, where `weights` is a dictionary
#
#     { 0 : weight_0, 1 : weight_1 }
#
# as specified in the formula above.
#
# **Note**: As an alternative, you can also use `sklearn.utils.class_weight` to do the calculation.
#
# **TODO: Complete the template to**
#
# -  Build a network consisting of a single logistic regression classifier (done for you!)
# -  Compile it using the same parameters as shown in the coding video, except we will use the `Adam` optimizer:
# >          optimizer='adam'
# -  Train it for **100** epochs, calculating the class weights explicitly as shown or using `sklearn.utils.class_weight` (look up the docs!)
# -  Display the training loss and accuracy curves using `plot_history`
# -  Complete the graded question

# %%
# Try a baseline model consisting of a single logistic regression classifier.
# This is very similar to sklearn's LogisticRegression model. 

n_epochs = 100

# We use Sequential to build a simple classification network from
# a list of layers, and print the summary

# Uncomment this when you have defined X_train:

model_baseline = keras.Sequential(
    [
       keras.layers.Input(shape=(X_train.shape[1],)),     # Explicit input layer
       keras.layers.Dense(1, activation="sigmoid")
    ]
)


model_baseline.compile(optimizer="adam", 
                       loss="mse", 
                       metrics=["accuracy"])

baseline_history = model_baseline.fit(X_train_scaled,
                                      y_train,
                                      epochs = n_epochs,
                                      verbose = 1
                                      )
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6879 - loss: 0.2206
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7275 - loss: 0.1970
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7582 - loss: 0.1770
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7868 - loss: 0.1608
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8132 - loss: 0.1469
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8308 - loss: 0.1351
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8418 - loss: 0.1252
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8505 - loss: 0.1169
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8681 - loss: 0.1093
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8769 - loss: 0.1028
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8835 - loss: 0.0971
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8989 - loss: 0.0919
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9099 - loss: 0.0868
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9099 - loss: 0.0824
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9121 - loss: 0.0780
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9187 - loss: 0.0741
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9253 - loss: 0.0704
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9275 - loss: 0.0668
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9363 - loss: 0.0634
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9363 - loss: 0.0602
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9385 - loss: 0.0572
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9451 - loss: 0.0548
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9495 - loss: 0.0526
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9495 - loss: 0.0507
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9516 - loss: 0.0491
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9538 - loss: 0.0476
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9560 - loss: 0.0462
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9560 - loss: 0.0449
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9582 - loss: 0.0438
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.0428
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.0419
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9582 - loss: 0.0409
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9604 - loss: 0.0400
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9604 - loss: 0.0392
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9626 - loss: 0.0384
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.0377
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.0370
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.0363
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9692 - loss: 0.0357
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9692 - loss: 0.0352
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.0346
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.0340
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.0335
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.0330
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.0326
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.0321
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.0317
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.0313
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9714 - loss: 0.0309
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9714 - loss: 0.0305
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9714 - loss: 0.0301
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9714 - loss: 0.0298
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9758 - loss: 0.0294
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0291
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0288
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9758 - loss: 0.0285
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9758 - loss: 0.0282
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9758 - loss: 0.0279
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0276
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0273
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0271
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0268
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9780 - loss: 0.0266
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0264
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0261
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0259
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0257
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0255
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9802 - loss: 0.0253
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0251
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0249
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0247
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0245
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9802 - loss: 0.0243
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0241
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0240
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0238
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0236
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0235
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0233
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0232
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0230
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0228
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0227
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0225
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0224
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0223
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0221
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0220
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0219
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0217
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0216
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0215
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0214
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0213
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0211
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0210
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0209
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0208
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0207

# %%
baseline_history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss'])

# %%
baseline_history.history["loss"]
# Out:
# [0.2206040918827057,
#  0.1970079392194748,
#  0.17696943879127502,
#  0.16077671945095062,
#  0.14686846733093262,
#  0.1351071149110794,
#  0.12522608041763306,
#  0.11693285405635834,
#  0.10934747010469437,
#  0.10279566049575806,
#  0.09709752351045609,
#  0.09189306199550629,
#  0.08678866922855377,
#  0.08236248046159744,
#  0.0780300423502922,
#  0.07411975413560867,
#  0.07038603723049164,
#  0.06677049398422241,
#  0.06342422217130661,
#  0.060183778405189514,
#  0.057204458862543106,
#  0.05483149737119675,
#  0.05262799561023712,
#  0.05072673037648201,
#  0.04908331111073494,
#  0.04755479469895363,
#  0.04615853726863861,
#  0.0449085496366024,
#  0.04382307827472687,
#  0.04279603809118271,
#  0.041852932423353195,
#  0.04091641306877136,
#  0.04003624618053436,
#  0.039228152483701706,
#  0.03842320293188095,
#  0.037673503160476685,
#  0.03701755777001381,
#  0.036341145634651184,
#  0.03572716936469078,
#  0.03515131399035454,
#  0.034594178199768066,
#  0.03400237858295441,
#  0.03350391611456871,
#  0.03302645683288574,
#  0.03255220875144005,
#  0.03208690881729126,
#  0.03166920691728592,
#  0.03128848969936371,
#  0.030868368223309517,
#  0.03050295263528824,
#  0.030125096440315247,
#  0.029778746888041496,
#  0.029439622536301613,
#  0.029089683666825294,
#  0.0287955142557621,
#  0.028462281450629234,
#  0.028159046545624733,
#  0.027880042791366577,
#  0.027602626010775566,
#  0.027325311675667763,
#  0.02707131952047348,
#  0.026823192834854126,
#  0.026570357382297516,
#  0.026366880163550377,
#  0.02610785886645317,
#  0.025893310084939003,
#  0.025670429691672325,
#  0.025464365258812904,
#  0.02525634504854679,
#  0.025065084919333458,
#  0.02485056221485138,
#  0.02465810813009739,
#  0.02447493001818657,
#  0.02429216168820858,
#  0.02413281612098217,
#  0.023954642936587334,
#  0.0237888190895319,
#  0.02361886575818062,
#  0.02347314916551113,
#  0.023296069353818893,
#  0.02317897044122219,
#  0.02299223281443119,
#  0.022827673703432083,
#  0.022682994604110718,
#  0.022542081773281097,
#  0.02241174690425396,
#  0.022264745086431503,
#  0.022142630070447922,
#  0.022006291896104813,
#  0.021874208003282547,
#  0.021745899692177773,
#  0.02161143720149994,
#  0.021500522270798683,
#  0.02136687934398651,
#  0.021254772320389748,
#  0.021124791353940964,
#  0.021007603034377098,
#  0.02088673785328865,
#  0.0207954254001379,
#  0.020695464685559273]

# %%
baseline_history.history["accuracy"]
# Out:
# [0.687912106513977,
#  0.7274725437164307,
#  0.7582417726516724,
#  0.7868131995201111,
#  0.8131868243217468,
#  0.8307692408561707,
#  0.8417582511901855,
#  0.8505494594573975,
#  0.8681318759918213,
#  0.8769230842590332,
#  0.8835164904594421,
#  0.898901104927063,
#  0.9098901152610779,
#  0.9098901152610779,
#  0.9120879173278809,
#  0.9186813235282898,
#  0.9252747297286987,
#  0.9274725317955017,
#  0.9362637400627136,
#  0.9362637400627136,
#  0.9384615421295166,
#  0.9450549483299255,
#  0.9494505524635315,
#  0.9494505524635315,
#  0.9516483545303345,
#  0.9538461565971375,
#  0.9560439586639404,
#  0.9560439586639404,
#  0.9582417607307434,
#  0.9582417607307434,
#  0.9582417607307434,
#  0.9582417607307434,
#  0.9604395627975464,
#  0.9604395627975464,
#  0.9626373648643494,
#  0.9670329689979553,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9692307710647583,
#  0.9714285731315613,
#  0.9714285731315613,
#  0.9714285731315613,
#  0.9714285731315613,
#  0.9758241772651672,
#  0.9758241772651672,
#  0.9758241772651672,
#  0.9758241772651672,
#  0.9758241772651672,
#  0.9758241772651672,
#  0.9758241772651672,
#  0.9758241772651672,
#  0.9758241772651672,
#  0.9780219793319702,
#  0.9780219793319702,
#  0.9780219793319702,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9802197813987732,
#  0.9846153855323792,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821,
#  0.9868131875991821]

# %%
plt.title("Training Loss Over Epochs")
plt.plot(range(1, n_epochs+1), baseline_history.history["loss"])
plt.xlabel("Epoch")
plt.ylabel("Training Loss (MSE)")
plt.xticks(range(1, n_epochs+1))
plt.show()

print(f'Final Training Loss: {baseline_history.history["loss"][-1]:4f}')
# Out:
# Final Training Loss: 0.022169

# %%
plt.title("Training Accuracy Over Epochs")
plt.plot(range(1, n_epochs+1), baseline_history.history["accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.xticks(range(1, n_epochs+1))
plt.show()

print(f'Final Training Accuracy: {baseline_history.history["accuracy"][-1]:4f}')
# Out:
# Final Training Loss: 0.986813

# %%
# Set a1c to the final training accuracy (at epoch 100)
# You MUST use an expression here, not a constant from inspecting the results

a1c = baseline_history.history["accuracy"][-1]

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a1c = {a1c:.4f}')
# Out:
# a1c = 0.9868

# %% [markdown]
# ### Part D: Testing
#
# - Calculate the testing loss and accuracy and answer the graded question.
# - Print out both with appropriate labels
# - Answer the graded question

# %%
# Evaluate on test set

test_loss, test_accuracy = model_baseline.evaluate(
    X_test_scaled,
    y_test,
    verbose=0
)

print(f"Test Loss: {test_loss: .4f}")
# Out:
# Test Loss:  0.0287

# %%
# Set a1d to the final testing accuracy
# Use the appropriate variable; do not insert a constant from inspection of the results

a1d = test_accuracy             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a1d = {a1d:.4f}')
# Out:
# a1d = 0.9825

# %% [markdown]
# ## Problem Two: Explore alternate network designs
#
# For the remaining problems, you will experiment with several different network designs.
#
# For Problem Two, redo the work you did in Parts C and D of Problem One, but with a network with a single hidden layer of 16 neurons, using the sigmoid activation function, which
# will have the following summary chart (the layer name may be different than shown here):
#
# ![Screenshot 2025-05-14 at 9.53.39 PM.png](attachment:289e078f-0957-43a2-b756-1b11145abf9a.png)
#
#
# Then answer the graded questions.

# %%
n_epochs = 100

model2 = keras.Sequential(
    [
       keras.layers.Input(shape=(X_train.shape[1],)),     
        keras.layers.Dense(16, activation="sigmoid"),
       keras.layers.Dense(1, activation="sigmoid")
    ]
)


model2.compile(optimizer="adam", 
                       loss="mse", 
                       metrics=["accuracy"])

history2 = model2.fit(X_train_scaled,
                            y_train,
                            epochs = n_epochs,
                            verbose = 1
                            )
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5407 - loss: 0.2230
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7451 - loss: 0.1799
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8615 - loss: 0.1479
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9055 - loss: 0.1247
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9165 - loss: 0.1071
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9209 - loss: 0.0946
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9363 - loss: 0.0851
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9407 - loss: 0.0773
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9495 - loss: 0.0713
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9495 - loss: 0.0662
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9516 - loss: 0.0618
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9538 - loss: 0.0581
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9538 - loss: 0.0549
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9582 - loss: 0.0519
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9604 - loss: 0.0494
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9626 - loss: 0.0471
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9648 - loss: 0.0451
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.0432
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.0416
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.0399
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.0385
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.0371
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.0359
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9714 - loss: 0.0347
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9714 - loss: 0.0337
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9714 - loss: 0.0327
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9736 - loss: 0.0318
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9736 - loss: 0.0310
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9736 - loss: 0.0302
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9736 - loss: 0.0294
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0287
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0281
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9780 - loss: 0.0274
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9780 - loss: 0.0268
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0262
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9780 - loss: 0.0257
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0252
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0247
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0243
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0238
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0234
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0230
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0227
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0223
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0220
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0217
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0214
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0211
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0208
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9824 - loss: 0.0205
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0202
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0200
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0197
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0195
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9824 - loss: 0.0193
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0191
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0188
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9846 - loss: 0.0186
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9846 - loss: 0.0184
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9846 - loss: 0.0183
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0181
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0178
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0177
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0175
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0173
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0172
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9868 - loss: 0.0170
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0169
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0167
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9868 - loss: 0.0166
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0164
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0163
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0162
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0161
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0159
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0158
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0157
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0156
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0155
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0154
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0153
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0151
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0150
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0149
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0149
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0148
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9868 - loss: 0.0147
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0146
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0145
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0144
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0143
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0142
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0141
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0140
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0140
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0139
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0138
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0138
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0137
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0136

# %%
plt.title("Training Loss Over Epochs")
plt.plot(range(1, n_epochs+1), history2.history["loss"])
plt.xlabel("Epoch")
plt.ylabel("Training Loss (MSE)")
plt.xticks(range(1, n_epochs+1))
plt.show()

print(f'Final Training Loss: {history2.history["loss"][-1]:4f}')
# Out:
# Final Training Loss: 0.013626

# %%
plt.title("Training Accuracy Over Epochs")
plt.plot(range(1, n_epochs+1), history2.history["accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.xticks(range(1, n_epochs+1))
plt.show()

print(f'Final Training Accuracy: {history2.history["accuracy"][-1]:4f}')
# Out:
# Final Training Accuracy: 0.989011

# %%
# Evaluate on test set

test_loss, test_accuracy = model2.evaluate(
    X_test_scaled,
    y_test,
    verbose=0
)

print(f"Test Loss: {test_loss: .4f}")
# Out:
# Test Loss:  0.0254

# %%
# Set a2a to the final training accuracy
# Use the appropriate variable or expression; do not insert a constant from inspection of the results

a2a = baseline_history.history["accuracy"][-1]             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a2a = {a2a:.4f}')
# Out:
# a2a = 0.9868

# %%
# Set a2b to the final testing accuracy
# Use the appropriate variable; do not insert a constant from inspection of the results

a2b = test_accuracy             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a2b = {a2b:.4f}')
# Out:
# a2b = 0.9649

# %% [markdown]
# ## Problem Three: Explore alternate network designs
#
#
# For Problem Three, redo the work you did in Parts C and D of Problem One, but with a network with a  hidden layer of 64 neurons,
# using the sigmoid activation function, which
# will have the following summary chart:
#
# ![Screenshot 2025-05-14 at 9.53.30 PM.png](attachment:1d505d45-e05e-4c0d-b125-70c1697ef5ba.png)
#
#
# Then answer the graded questions.

# %%
n_epochs = 100

model3 = keras.Sequential(
    [
       keras.layers.Input(shape=(X_train.shape[1],)),     
        keras.layers.Dense(64, activation="sigmoid"),
       keras.layers.Dense(1, activation="sigmoid")
    ]
)


model3.compile(optimizer="adam", 
                       loss="mse", 
                       metrics=["accuracy"])

history3 = model3.fit(X_train_scaled,
                            y_train,
                            epochs = n_epochs,
                            verbose = 1
                            )
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6440 - loss: 0.2318
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8549 - loss: 0.1484
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8989 - loss: 0.1073
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.0851
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9231 - loss: 0.0716
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9429 - loss: 0.0622
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9451 - loss: 0.0556
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9495 - loss: 0.0504
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9582 - loss: 0.0459
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9648 - loss: 0.0425
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9692 - loss: 0.0396
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9736 - loss: 0.0371
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9780 - loss: 0.0351
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9802 - loss: 0.0334
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9846 - loss: 0.0317
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0302
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0289
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0278
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9846 - loss: 0.0269
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9846 - loss: 0.0259
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0251
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0243
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0235
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0229
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0224
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0218
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0213
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0208
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0204
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0199
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0196
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0192
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0189
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0186
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0183
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0180
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0177
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0174
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0171
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0169
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0168
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0166
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9868 - loss: 0.0163
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0161
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0159
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0158
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0156
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0154
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0153
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0151
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0150
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9890 - loss: 0.0148
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0147
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0145
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0144
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0143
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0143
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0142
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0140
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0138
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0138
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0136
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0136
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0134
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0133
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0133
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0132
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0132
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0130
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0129
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0128
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0128
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0126
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0126
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0125
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0125
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0124
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0123
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0122
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0122
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0121
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0121
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0121
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0120
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0118
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0119
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0117
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0117
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0116
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0116
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9890 - loss: 0.0115
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0115
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0114
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0114
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0113
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0113
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0112
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0112
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0112
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0111

# %%
plt.title("Training Loss Over Epochs")
plt.plot(range(1, n_epochs+1), history3.history["loss"])
plt.xlabel("Epoch")
plt.ylabel("Training Loss (MSE)")
plt.xticks(range(1, n_epochs+1))
plt.show()

print(f'Final Training Loss: {history3.history["loss"][-1]:4f}')
# Out:
# Final Training Loss: 0.011091

# %%
plt.title("Training Accuracy Over Epochs")
plt.plot(range(1, n_epochs+1), history3.history["accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.xticks(range(1, n_epochs+1))
plt.show()

print(f'Final Training Accuracy: {history3.history["accuracy"][-1]:4f}')
# Out:
# Final Training Accuracy: 0.989011

# %%
# Evaluate on test set

test_loss, test_accuracy = model3.evaluate(
    X_test_scaled,
    y_test,
    verbose=0
)

print(f"Test Loss: {test_loss: .4f}")
# Out:
# Test Loss:  0.0234

# %%
# Set a3a to the final training accuracy
# Use the appropriate variable or expression; do not insert a constant from inspection of the results

a3a = history3.history["accuracy"][-1]             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a3a = {a3a:.4f}')
# Out:
# a3a = 0.9890

# %%
# Set a3b to the final testing accuracy
# Use the appropriate variable; do not insert a constant from inspection of the results

a3b = test_accuracy             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a3b = {a3b:.4f}')
# Out:
# a3b = 0.9561

# %% [markdown]
# ## Problem Four: Explore alternate network designs
#
#
# For Problem Four, redo the work you did in Parts C and D of Problem One, but with a network with  a hidden layer of 256 neurons, using the sigmoid activation function, which
# will have the following summary chart:
#
# ![Screenshot 2025-05-14 at 9.53.20 PM.png](attachment:464f1603-0ac4-4ca2-8f3e-affe3ee25b5a.png)
#
#
# Then answer the graded questions.

# %%
n_epochs = 100

model4 = keras.Sequential(
    [
       keras.layers.Input(shape=(X_train.shape[1],)),     
        keras.layers.Dense(256, activation="sigmoid"),
       keras.layers.Dense(1, activation="sigmoid")
    ]
)


model4.compile(optimizer="adam", 
                       loss="mse", 
                       metrics=["accuracy"])

history4 = model4.fit(X_train_scaled,
                            y_train,
                            epochs = n_epochs,
                            verbose = 1
                            )
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7473 - loss: 0.1688
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9385 - loss: 0.0816
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9319 - loss: 0.0571
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9516 - loss: 0.0466
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.0397
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0354
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0322
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9758 - loss: 0.0303
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0274
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0265
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0248
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0240
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9824 - loss: 0.0231
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9824 - loss: 0.0214
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0214
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0203
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0195
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0189
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0187
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0180
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0176
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0173
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0168
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0165
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0161
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0158
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0158
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0154
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0151
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9868 - loss: 0.0151
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0148
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9890 - loss: 0.0146
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0143
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9868 - loss: 0.0142
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0139
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0137
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0137
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0135
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0134
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0134
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0132
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0128
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0128
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0128
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0124
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0126
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0124
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0122
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0124
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0121
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0121
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0120
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0117
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0117
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0116
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0115
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0115
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0117
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0114
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0114
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0110
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0113
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9912 - loss: 0.0111
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0110
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0110
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0108
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0107
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0107
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0107
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0106
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0106
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0105
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0103
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0104
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0103
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0102
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0101
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0103
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0104
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0100
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0099
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0098
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0098
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0099
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0097
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9912 - loss: 0.0096
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.0096
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0101
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9912 - loss: 0.0099
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0097
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0098
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0094
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0093
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0094
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9912 - loss: 0.0092
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0092
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0093
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0091
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0092
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0093

# %%
plt.title("Training Loss Over Epochs")
plt.plot(range(1, n_epochs+1), history4.history["loss"])
plt.xlabel("Epoch")
plt.ylabel("Training Loss (MSE)")
plt.xticks(range(1, n_epochs+1))
plt.show()

print(f'Final Training Loss: {history4.history["loss"][-1]:4f}')
# Out:
# Final Training Loss: 0.009298

# %%
plt.title("Training Accuracy Over Epochs")
plt.plot(range(1, n_epochs+1), history4.history["accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.xticks(range(1, n_epochs+1))
plt.show()

print(f'Final Training Accuracy: {history4.history["accuracy"][-1]:4f}')
# Out:
# Final Training Accuracy: 0.991209

# %%
# Evaluate on test set

test_loss, test_accuracy = model4.evaluate(
    X_test_scaled,
    y_test,
    verbose=0
)

print(f"Test Loss: {test_loss: .4f}")
# Out:
# Test Loss:  0.0309

# %%
# Set a4a to the final training accuracy
# Use the appropriate variable or expression; do not insert a constant from inspection of the results

a4a = history4.history["accuracy"][-1]             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a4a = {a4a:.4f}')
# Out:
# a4a = 0.9912

# %%
# Set a4b to the final testing accuracy
# Use the appropriate variable; do not insert a constant from inspection of the results

a4b = test_accuracy             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a4b = {a4b:.4f}')
# Out:
# a4b = 0.9474

# %% [markdown]
# ## Problem Five: Explore alternate network designs
#
#
# For Problem Five, redo the work you did in Parts C and D of Problem One, but with a network with two hidden layers of 64  and 32 neurons, using the sigmoid activation function for all layers, which
# will have the following summary chart:
#
# ![Screenshot 2025-05-14 at 9.52.42 PM.png](attachment:b6094f80-be1d-4ade-be21-44e24aab768f.png)
#
# Then answer the graded questions.

# %%
n_epochs = 100

model5 = keras.Sequential(
    [
       keras.layers.Input(shape=(X_train.shape[1],)),     
        keras.layers.Dense(64, activation="sigmoid"),
        keras.layers.Dense(32, activation="sigmoid"),
       keras.layers.Dense(1, activation="sigmoid")
    ]
)


model5.compile(optimizer="adam", 
                       loss="mse", 
                       metrics=["accuracy"])

history5 = model5.fit(X_train_scaled,
                            y_train,
                            epochs = n_epochs,
                            verbose = 1
                            )
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6176 - loss: 0.2281
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6571 - loss: 0.1884
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8176 - loss: 0.1499
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9099 - loss: 0.1183
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9187 - loss: 0.0928
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9275 - loss: 0.0748
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9297 - loss: 0.0622
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9451 - loss: 0.0526
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9495 - loss: 0.0453
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9648 - loss: 0.0397
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9714 - loss: 0.0354
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0319
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9758 - loss: 0.0290
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0268
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0249
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0233
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0220
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0209
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0199
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0192
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0185
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0183
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0174
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0169
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0165
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0161
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9868 - loss: 0.0157
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0153
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0150
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0147
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0145
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0142
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0140
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0138
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0136
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0135
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0137
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0131
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0128
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0128
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0127
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0124
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0124
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0123
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0121
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9868 - loss: 0.0120
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0121
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0118
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0116
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0116
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0115
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0113
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0113
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0113
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0111
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0110
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0109
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0108
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0108
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0106
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0106
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0106
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0104
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0105
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0103
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0103
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0101
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0103
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0101
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0100
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0099
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0102
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0101
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0099
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0097
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9912 - loss: 0.0097
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0096
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9890 - loss: 0.0095
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0095
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0095
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0093
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0094
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0093
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0092
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0092
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0092
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0090
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0089
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9912 - loss: 0.0089
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0091
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0090
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0088
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0087
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.0088
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.0087
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9912 - loss: 0.0086
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0085
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0086
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0085
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0086

# %%
plt.title("Training Loss Over Epochs")
plt.plot(range(1, n_epochs+1), history5.history["loss"])
plt.xlabel("Epoch")
plt.ylabel("Training Loss (MSE)")
plt.xticks(range(1, n_epochs+1))
plt.show()

print(f'Final Training Loss: {history5.history["loss"][-1]:4f}')
# Out:
# Final Training Loss: 0.008554

# %%
plt.title("Training Accuracy Over Epochs")
plt.plot(range(1, n_epochs+1), history5.history["accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.xticks(range(1, n_epochs+1))
plt.show()

print(f'Final Training Accuracy: {history5.history["accuracy"][-1]:4f}')
# Out:
# Final Training Accuracy: 0.991209

# %%
# Evaluate on test set

test_loss, test_accuracy = model5.evaluate(
    X_test_scaled,
    y_test,
    verbose=0
)

print(f"Test Loss: {test_loss: .4f}")
# Out:
# Test Loss:  0.0300

# %%
# Set a5a to the final training accuracy
# Use the appropriate variable or expression; do not insert a constant from inspection of the results

a5a = history5.history["accuracy"][-1]             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a5a = {a5a:.4f}')
# Out:
# a5a = 0.9912

# %%
# Set a5b to the final testing accuracy
# Use the appropriate variable; do not insert a constant from inspection of the results

a5b = test_accuracy             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a5b = {a5b:.4f}')
# Out:
# a5b = 0.9561

# %% [markdown]
# ## Reflection Questions:
#
# You won't be graded on these, and you don't need to write anything, but here are some things to think about after completing the experiments.
#
# 1. After the baseline, we tried wider and wider models, and then a deeper model. Which idea worked better in terms of training accuracy (at least for this data split)? What model would you try next to test this hypothesis?
#
# 2. What effect did these experiments have on the testing accuracy?  Can you suggest an explanation for this? Rather than me giving you ideas, have a conversation with `ChatGPT` in which you describe your experiments, and the dataset, and explore with it why the testing results turned out this way.
#
# 3. What do you think would happen if you tried running the same experiments with a different random seed (and hence a different split in a fairly small dataset)?
